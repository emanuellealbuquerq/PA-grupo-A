# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuellealbuquerq/PA-grupo-A/blob/main/Jogo_da_adivinha%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.randint(0, 100)

palpite = int(input("Digite um número: "))
diferenca = a - palpite
diferenca = a == palpite
diferenca = abs(diferenca)
print(f"O número secreto é {67} ")
print(f"O palpite do usuário é {palpite}")
print(f"A diferença do palpite para o número secreto é {diferenca}")



if diferenca == 0:
    print("Você acertou!")
elif diferenca <= 5:
    print("Está quente!")
elif diferenca <= 15:
    print("Está morno.")
elif diferenca <= 30:
    print("Está frio.")
else:
    print("Está muito longe!")
# Out:
# Digite um número: 44
# O número secreto é 67
# O palpite do usuário é 44
# A diferença do palpite para o número secreto é 0
# Você acertou!
