# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuellealbuquerq/PA-grupo-A/blob/main/programa%C3%A7%C3%A3o_17_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operadores aritimeticos

# %%
#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

soma = a+b
subtracao = a-b
multiplicacao = a*b
divisao = a/b
div_int = a/b
resto = a%b
potencia = a**b

#Saida
print(" ")
print("--------operadores aritimeticos----------")
print(" ")
print("---------soma-------")
print(" ")
print (f"o resultado da soma de {a} e {b} é igual a : {soma}")
print(" ")
print("---------subtracao-------")
print(" ")
print (f"o resultado da subtracao de {a} e {b} é igual a : {subtracao}")
print(" ")
print("---------multiplicacao-------")
print(" ")
print (f"o resultado da multiplicacao de {a} e {b} é igual a : {multiplicacao}")
print(" ")
print("---------divisao-------")
print(" ")
print (f"o resultado da divisao de {a} e {b} é igual a : {divisao}")
print(" ")
print("---------divisao inteira-------")
print(" ")
print (f"o resultado da divisao inteira de {a} e {b} é igual a : {div_int}")
print(" ")
print("---------resto-------")
print(" ")
print (f"o resultado da resto de {a} e {b} é igual a : {resto}")
print(" ")
print("---------potencia-------")
print(" ")
print (f"o resultado  da potencia de {a} e {b} é igual a : {potencia}")
print(" ")
print("---------------")
# Out:
# digite um numero 16
# digite um numero 14
#
# --------operadores aritimeticos----------
#
# ---------soma-------
#
# o resultado da soma de 16 e 14 é igual a : 30
#
# ---------subtracao-------
#
# o resultado da subtracao de 16 e 14 é igual a : 2
#
# ---------multiplicacao-------
#
# o resultado da multiplicacao de 16 e 14 é igual a : 224
#
# ---------divisao-------
#
# o resultado da divisao de 16 e 14 é igual a : 1.1428571428571428
#
# ---------divisao inteira-------
#
# o resultado da divisao inteira de 16 e 14 é igual a : 1.1428571428571428
#
# ---------resto-------
#
# o resultado da resto de 16 e 14 é igual a : 2
#
# ---------potencia-------
#
# o resultado  da potencia de 16 e 14 é igual a : 72057594037927936
#
# ---------------

# %% [markdown]
# Soma

# %%
# operadores aritimeticos
#Fazer um programa e calcula operações com 2 numeros

#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

soma = a + b

#Saida
print(" ")
print("--------operadores aritimeticos----------")
print(" ")
print("---------soma-------")
print(" ")
print (f"o resultado da soma de {a} mais {b} é igual a : {soma}")
print(" ")
print("---------------")
# Out:
# digite um numero 4
# digite um numero2
#
# --------operadores aritimeticos----------
#
# ---------soma-------
#
# o resultado da soma de 4 mais 2 é igual a : 6
#
# ---------------

# %% [markdown]
# Subtração

# %%
#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

total = a-b

#Saida

print(" ")
print("--------operadores aritimeticos----------")
print(" ")
print("---------subtracao-------")
print(" ")
print (f"o resultado da subtracao de {a} menos {b} é igual a : {total}")
print(" ")
print("---------------")
# Out:
# digite um numero7
# digite um numero9
#
# --------operadores aritimeticos----------
#
# ---------subtracao-------
#
# o resultado da subtracao de 7 menos 9 é igual a : -2
#
# ---------------

# %% [markdown]
# Multiplicação

# %%
#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

total = a * b

#Saida
print(" ")
print("--------operadores aritimeticos----------")
print(" ")
print("---------multiplicacao-------")
print(" ")
print (f"o resultado da multiplicacao de {a} e {b} é igual a : {total}")
print(" ")
print("---------------")
# Out:
# digite um numero 7
# digite um numero2
#
# --------operadores aritimeticos----------
#
# ---------multiplicacao-------
#
# o resultado da multiplicacao de 7 e 2 é igual a : 14
#
# ---------------

# %% [markdown]
# Divisão

# %%
#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

total = a/b

#Saida
print(" ")
print("--------operadores aritimeticos----------")
print(" ")
print("---------divisao-------")
print(" ")
print (f"o resultado da divisao de {a} e {b} é igual a : {total}")
print(" ")
print("---------------")
# Out:
# digite um numero 12
# digite um numero 3
#
# --------operadores aritimeticos----------
#
# ---------divisao-------
#
# o resultado da divisao de 12 e 3 é igual a : 4.0
#
# ---------------

# %%
#Operadores relacionais

#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

#Comparação

igual = a == b

#Saida

print(igual)
# Out:
# digite um numero 3
# digite um numero 2
# False

# %%
#Operadores relacionais

#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

#Comparação

diferente = a !=b

#Saida

print(diferente)
# Out:
# digite um numero 3
# digite um numero 6
# True

# %%
#Operadores relacionais

#Entrada

a =int(input("digite um numero"))
b =int(input("digite um numero"))

#Processamento

#Comparação

maior = a > b
menor = a < b
maiorigual = a >= b
menorigual = a <= b

#Saida

print(maior)
print(menor)
print(maiorigual)
print(menorigual)
# Out:
# digite um numero 16
# digite um numero 12
# True
# False
# True
# False

# %%
#Fazer um programa que converte a temperatura

#Entrada

c= int(input("Digite a temperatura"))

#Processamento

temperatura = (c * 9/5)+32

#Saida

print(f"a temperatura de {c} °C é equivalente a {temperatura} °F")
# Out:
# Digite a temperatura 32
# a temperatura de 32 °C é equivalente a 89.6 °F

# %%
#Fazer um programa que converte km em metros

#Entrada

k =int(input("Digite o km"))

#Processamento

metros = (k * 1000)

#Saida

print(f"o quilometro de {k} km é equivalente a {metros}")
# Out:
# Digite o km 5
# o quilometro de 5 km é equivalente a 5000

# %%
#Fazer um programa que converte horas em minutos

#Entrada

h =int(input("Digite as horas"))

#Processamento

minutos = (h * 60)

#Saida

print(f"as horas de {h} horas é equivalente a {minutos}")
# Out:
# Digite as horas 3
# as horas de 3 horas é equivalente a 180
