# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuellealbuquerq/PA-grupo-A/blob/main/Programa%C3%A7%C3%A3o_02_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.random()

print(a)
# Out:
# 0.8644085718077712

# %%
import random

a = random.randint(0, 100)

print(a)
# Out:
# 81

# %%
#Fazer um jogo de adivinhação

#O usuário irá digitar um número de 0 a 10 para adivinhar o número secreto
#O usuário terá 03 tentativas para acerta o número
#O programa deverá imprimir uma mensagem se o palpite de usuário e maior ou menor que o número secreto
#O progrma deverá imprimir uma mensagem de quente,morno ou frio

#Regras
#Se a diferença do palpite para o número secretor for 3 - frio,2 - morno e 1 - quente

número = int(input("Digite um número de 0 á 10: "))

import random

a = random.randint(0,10)

if número == 3:
 print(f"Está frio!")

elif número == 2:
  print(f"Está morno!")

elif número == 1:
  print(f"Está quente!")

else:
  print()
