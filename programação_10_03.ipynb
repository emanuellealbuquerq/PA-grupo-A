# %% [markdown]
# <a href="https://colab.research.google.com/github/emanuellealbuquerq/PA-grupo-A/blob/main/programa%C3%A7%C3%A3o_10_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Entrada
comprimento = float (input("Digite o comprimento do retagulo:")
Altura = float(input("Digite a altura do retangulo:")

#Processamento
 Area = comprimento *altura

 #saida
  print(f "o total da area do retangulo é: {area} ")

  digite o comprimento do retangulo:6
  digite a altura do retangulo:3
  o total da area do retangulo:18

# %% [markdown]
# Fazer um cadastro de um usuario
#
# objetivo trabalhar com string (src)
#
# entrada de dados:Nome e idade
#
# processamento:armazenar os dados

# %%
#Entrada
nome = str(input("Digite seu nome"))
idade = int(input("Digite sua idade")

#Processamento

  print =(f"olá {nome},se seja bem vindo"
  print =(f"voce tem {idade} anos"

  Digite seu nome:Emanuelle
  Digite sua idade: 15

  Olá Emanuelle,seja bem vinda
  Voce tem 15 anos

# %% [markdown]
# Fazer um programa que calcule o dobro de um número
#
# Entrada:um número
#
# Processamento:calcula um dobro
#
# Saida:mostra o resultado

# %%
#Entrada

numero = float (input("Digite um número: "))

#Processamento

total = numero * 2

#Saida

print (f"o dobro do numero {numero} é igual a: {total}")
# Out:
# Digite um número: 9
# o dobro do numero 9.0 é igual a: 18.0

# %% [markdown]
# Escrever um programa que calcula as medias do aluno
#
# Entrada:nome,idade e as 04 notas do bimestre
#
# Processamento:calcular as medias
#
# saida:mostra as nome do aluno e a media obtida

# %%
#Entrada
nome = str(input("digite o nome do aluno"))
idade = int(input("digite a idade do aluno"))
primeira = float(input("digite a nota do bimestre"))
segunda  = float(input("digite a nota bimestre"))
terceira = float(input("digite a nota bimestre"))
quarta = float(input("digite a nota bimestre"))

 #Processamento
total = (primeira + segunda + terceira + quarta)/4

  #saida
]print(f"a media do aluno {nome},com{idade} anos é: {total}")
# Out:
# digite o nome do alunoclara
# digite a idade do aluno14
# digite a nota do bimestre7.5
# digite a nota bimestre10
# digite a nota bimestre9.8
# digite a nota bimestre8.7
# a media do aluno clara ,com14 anos é: 9.0
